# %% [markdown]
# # SVD (Singular Value Decomposition)
#
#
#
#
#
# <script src="https://sagecell.sagemath.org/static/embedded_sagecell.js"></script>
# <script>
# sagecell.makeSagecell({inputLocation: '.sage'});
# </script>
#
# <div class="sage">
# import numpy as np
# A = np.array([[1,3,1],[0,1,2],[1,0,1]])
# U, S, VT = np.linalg.svd(A)
# print("U =")
# print(U)
# print("S =")
# print(S)
# print("VT =")
# print(VT)
#
# </div>
